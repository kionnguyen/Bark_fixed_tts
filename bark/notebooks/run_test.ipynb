# %%
# %cd ..
# %pip install .
# Out:
# e:\Side Hustle\Bark_tortoise_tts\bark
# Processing e:\side hustle\bark_tortoise_tts\bark
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Obtaining dependency information for boto3 from https://files.pythonhosted.org/packages/da/7e/ea3b898a2f7f8b698eb93d808cca4202e2e5ee1887715b28b42fb9b5c71c/boto3-1.28.60-py3-none-any.whl.metadata
# ...
#   Using cached encodec-0.1.1.tar.gz (3.7 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached funcy-2.0-py2.py3-none-any.whl (30 kB)
# ...

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models, save_as_prompt
from scipy.io.wavfile import write as write_wav
from IPython.display import Audio

# download and load all models
preload_models()
# generate audio from text
text_prompt = """
     Hello, my name is Suno. And, uh — and I like pizza. [laughs] 
     But I also have other interests such as playing tic tac toe.
"""
audio_array = generate_audio(text_prompt, history_prompt = "v2/en_speaker_3")
# # save audio to disk
write_wav("bark_generation.wav", SAMPLE_RATE, audio_array)
  
# # play text in notebook
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# No GPU being used. Careful, inference might be very slow!
# ...
# 100%|██████████| 29/29 [05:08<00:00, 10.64s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Side Hustle\Bark_tortoise_tts\bark\notebooks\run_test.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Side%20Hustle/Bark_tortoise_tts/bark/notebooks/run_test.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> audio_array
#
# NameError: name 'audio_array' is not defined

# %%
save_as_prompt(r"E:\Side Hustle\Bark_tortoise_tts\bark\bark\gen_prompts\first.npz", full_generation)

# %%
import numpy as np
full_generation = dict(np.load(r"E:\Side Hustle\Bark_tortoise_tts\bark\bark\gen_prompts\first.npz", allow_pickle=True))

# %%
full_generation
# Out:
# {'semantic_prompt': array([3255,  278, 3255, 1476,  278,   72, 9163,   10, 5458, 5458,   10,
#          302, 1075,  176, 9812, 9812, 1616,  292,  292, 3927, 3927, 9650,
#         6583,   32,   32,   32,   32,   32, 4972, 1997, 9461, 9461, 9461,
#         7396, 1087,  736, 1087, 3789,  188, 8084,   10,  188,   41, 8612,
#         6351, 7516, 1331,  366,  288,   41,   41, 8626, 2157, 2157, 6726,
#         2703, 4388,  288,   41,   41, 9261, 4212, 5721,  122,   59,   28,
#           28,   28,   28,   28,   28,   28, 1133, 4449, 9741, 9741, 9449,
#         1059, 6679, 1989,   41,   17, 2598, 7735, 7847, 7847,   32,   32,
#         1667, 4661, 9461, 1446, 1087, 1087,  783, 4838,   10,   56, 2459,
#         5555,  602,   10, 7150, 8428, 2459,   10,  602, 2009, 5458,   10,
#         5458,  147, 7551,  302,   10,   57, 7882, 7170, 8604, 2236, 1758,
#         1758, 4119,  321,  171,  255,   99,   41,  652, 5005, 5821, 7126,
# ...

# %%
full_generation.keys()
# Out:
# dict_keys(['semantic_prompt', 'coarse_prompt', 'fine_prompt'])

# %%
finetune = dict()
finetune['finetune'] = full_generation['fine_prompt']

# %%
np.savez(r"E:\Side Hustle\Bark_tortoise_tts\bark\bark\gen_prompts\first.npz", **finetune)

# %%
dict(np.load(r"E:\Side Hustle\Bark_tortoise_tts\bark\bark\gen_prompts\first.npz", allow_pickle=True))
# Out:
# {'finetune': array([[ 263,  792,  157, ...,  855,  106,  855],
#         [1010,  885,  942, ...,  740,  302,  740],
#         [ 423,  590,  159, ...,  653,  653, 1015],
#         ...,
#         [ 949,  624,  982, ...,  435,  632,   19],
#         [ 606,  184,  643, ...,  570,  853,  782],
#         [ 947,  700,  534, ...,  237,  989,  701]])}
